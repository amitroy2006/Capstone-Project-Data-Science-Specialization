# %% [markdown]
# # My Hotel in San Francisco

# %% [markdown]
# ## 1. Introduction of the Business Case

# %% [markdown]
# The aim of the subsequent analysis is to open up a new hotel in San Francisco. For that end, we identify highly attractive spots in the San Francisco Neighbourhood, for example by checking for the closeness of parks and recreation areas, closeness to the bart network and closeness to knots of highly attractive venues. We use data from the NYU spatial data repository in order to identify the Bart stations as well as the recreation areas. Also, we extract venues from Foursquare, identify highly frequented ones and map those onto the same map. We use a Kmeans algorithm to assign labels to the venues - we are looking for knots of these venues, i.e. spots where different labels come together in order to present the visitor with a diversified and varied selection of venues to visit during their stay.

# %%
import pandas as pd
import numpy as np
# !pip install folium
import folium

# %%
# latitude of sf 37.773972, longitude sf -122.431297
world_map = folium.Map(location=[37.773972, -122.431297], zoom_start=12)

# display world map
world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## get the json file with the bart stations
# !wget --quiet https://geo.nyu.edu/download/file/stanford-sp464ds6332-geojson.json
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
sf_bart_stations = r'stanford-sp464ds6332-geojson.json' # geojson file

# create a plain world map
world_map2 = folium.Map(location=[37.773972, -122.431297], zoom_start=12)
world_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sf_bart_stations
# Out:
# 'stanford-sp464ds6332-geojson.json'

# %%
import requests
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
import pandas.io.json

# %%
my_zones_load =  pandas.io.json.loads(requests.get('https://geo.nyu.edu/download/file/stanford-sp464ds6332-geojson.json').text)
folium.GeoJson(my_zones_load).add_to(world_map2)

# %% [markdown]
# ### to be continued

# %% [markdown]
# The following steps are undertaken in order to map park and recreations area on the San Francisco Map.

# %%
## import the park and recreation data for obtaining a cloropleth map later on 

## get the json file with the bart stations
# !wget --quiet https://geo.nyu.edu/download/file/ark28722-s7760p-geojson.json
    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
sf_parks_recreation = r'ark28722-s7760p-geojson.json' # geojson file

# %%
world_map2.choropleth(
    geo_data=sf_parks_recreation,
    key_on='properties.DISTRICT',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Crime Rate San Francisco'
)
world_map2
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/folium/folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
